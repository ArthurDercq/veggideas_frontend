# %%
import requests
import json
from random import randint
import pandas as pd

# %%
IDS = {-1}
APP_ID = "785b538a"
API_KEY = "01bde07232a776b52909d9876ae11db4"
VEGETABLE = ["carrot", "chicken"]
DIET = "high-fiber"
CALORIES = "100-800"


URL = f"https://api.edamam.com/api/recipes/v2?type=public&q={VEGETABLE}&app_id={APP_ID}&app_key={API_KEY}&diet={DIET}&calories={CALORIES}&field=label&field=url&field=dietLabels&field=healthLabels&field=ingredients&field=calories&field=cuisineType&field=mealType&field=totalTime"

# %%
def make_requests(url):
    response = requests.get(url)
    data = response.json()
    return data

recipes = make_requests(URL)

# %%
def get_recipes(vegetable_type):
    URL = f"https://api.edamam.com/api/recipes/v2?type=public&q={vegetable_type}&app_id={APP_ID}&app_key={API_KEY}&diet={DIET}&calories={CALORIES}&field=label&field=url&field=dietLabels&field=healthLabels&field=ingredients&field=calories&field=cuisineType&field=mealType&field=totalTime"

    recipes = make_requests(URL)
    return recipes

# %%
def get_recipes_details(number_of_recipes, final_prediction):
    recipe_list = []

    recipes = get_recipes(final_prediction)

    for _ in range(0, number_of_recipes):
        # Name of the recipe
        url = recipes["hits"][_]["recipe"]["url"]
        recipe_name = recipes['hits'][_]['recipe']['label']

        if not recipe_name:  # Skip recipes without a name
            continue

        # Recipe URL
        recipe_url = recipes["hits"][_]["recipe"]["url"]

        # List of ingredients and relative quantity
        list_ingredients = [item["text"] for item in recipes["hits"][_]["recipe"]["ingredients"]]


        # Type of diet
        recipe_type_diet = recipes["hits"][_]["recipe"]["healthLabels"][:3]

        # Calories of the recipe
        recipe_calories = round(recipes["hits"][_]["recipe"]["calories"])

        recipe_time = int(recipes["hits"][_]["recipe"]["totalTime"])

        recipe_meal_type = [meal.capitalize() for meal in recipes["hits"][_]["recipe"]["mealType"][0].split("/")]
        recipe_cuisine_type = recipes["hits"][_]["recipe"]["cuisineType"][0].capitalize()

        # Append recipe details to the list
        recipe_details = {
            "Recipe Name": recipe_name,
            "Ingredients": list_ingredients,
            "Diet Type": recipe_type_diet,
            "Calories": recipe_calories,
            "Time": recipe_time,
            "Meal Type": recipe_meal_type,
            "Cuisine": recipe_cuisine_type,
            "Recipe URL": recipe_url

        }
        recipe_list.append(recipe_details)

    # Convert the list of dictionaries into a dataframe
    df = pd.DataFrame(recipe_list)

    return df

# %%
data = get_recipes_details(10, "broccoli" )

# %%
data
# Out:
#                                          Recipe Name  \
# 0                                   Steamed Broccoli
# 1                                   Grilled Broccoli
# 2  Broccoli And Broccoli Rabe With Roasted Red Pe...
# 3                            Broccoli Baked Potatoes
# 4                                      Broccoli Beef
# 5              Usili Curry with Broccoli and Coconut
# 6                               Broccoli Winter Slaw
# 7              Christmas Broccoli: Broccoli Soffriti
# 8                  Broccoli Cheese Casserole recipes
# 9                                     Broccoli Salad
#
#                                          Ingredients  \
# 0  [1 bunch broccoli, Dijon Vinaigrette, for serv...
# 1  [2 heads broccoli, 2 tablespoons olive oil, 1/...
# 2  [3 large red bell peppers, 4 pounds broccoli, ...
# 3  [1 egg , beaten, 140.0g grated cheddar, 300.0g...
# 4  [2 teaspoons soy sauce, 1 teaspoons Shaoxing w...
# 5  [2 medium broccoli bunches, ½ grated coconut, ...
# 6  [1 Head Broccoli, 10 Brussels Sprouts Sprouts,...
# 7  [3 pounds fresh broccoli, with leaves, or broc...
# 8  [2 pounds broccoli, stems removed (can use veg...
# 9  [3 heads Broccoli, 1 x Red onion, 6 slices Bac...
#
#                                        Diet Type  Calories  Time  \
# 0               [Vegan, Vegetarian, Pescatarian]       225     0
# 1               [Vegan, Vegetarian, Pescatarian]       652    38
# 2               [Vegan, Vegetarian, Pescatarian]      1824     0
# 3     [Sugar-Conscious, Vegetarian, Pescatarian]      1515     0
# 4            [Dairy-Free, Egg-Free, Peanut-Free]      1066     0
# 5               [Vegan, Vegetarian, Pescatarian]       577    20
# 6               [Vegetarian, Pescatarian, Paleo]      1181     0
# 7  [Sugar-Conscious, Keto-Friendly, Pescatarian]       896    25
# 8         [Peanut-Free, Tree-Nut-Free, Soy-Free]      2817    55
# 9          [Dairy-Free, Gluten-Free, Wheat-Free]      3514     0
#
#          Meal Type         Cuisine  \
# 0  [Lunch, Dinner]         Italian
# 1  [Lunch, Dinner]         Italian
# 2  [Lunch, Dinner]         Italian
# 3  [Lunch, Dinner]  Central europe
# 4  [Lunch, Dinner]         British
# 5  [Lunch, Dinner]          Indian
# 6  [Lunch, Dinner]         Italian
# 7  [Lunch, Dinner]         Italian
# 8  [Lunch, Dinner]          French
# 9  [Lunch, Dinner]        American
#
#                                           Recipe URL
# 0  https://www.marthastewart.com/924840/steamed-b...
# 1   https://food52.com/recipes/6823-grilled-broccoli
# 2  http://www.bonappetit.com/recipes/2003/06/broc...
# 3          http://www.bbcgoodfood.com/recipes/12689/
# 4           http://norecipes.com/blog/broccoli-beef/
# 5  http://honestcooking.com/usili-curry-broccoli-...
# 6  http://glutenfreegirl.com/2010/01/broccoli-win...
# 7  https://www.foodnetwork.com/recipes/mario-bata...
# 8  http://www.simplyrecipes.com/recipes/broccoli_...
# 9  http://userealbutter.com/2009/02/22/broccoli-s...

# %%
def filter_diet_type(df, diet):
    filtered_df = df[df["Diet Type"].apply(lambda x: diet.capitalize() in x)]
    return filtered_df

# %%
filter_diet_type(data, "Vegetarian")
# Out:
#                                          Recipe Name  \
# 0                                   Steamed Broccoli
# 1                                   Grilled Broccoli
# 2  Broccoli And Broccoli Rabe With Roasted Red Pe...
# 3                            Broccoli Baked Potatoes
# 5              Usili Curry with Broccoli and Coconut
# 6                               Broccoli Winter Slaw
#
#                                          Ingredients  \
# 0  [1 bunch broccoli, Dijon Vinaigrette, for serv...
# 1  [2 heads broccoli, 2 tablespoons olive oil, 1/...
# 2  [3 large red bell peppers, 4 pounds broccoli, ...
# 3  [1 egg , beaten, 140.0g grated cheddar, 300.0g...
# 5  [2 medium broccoli bunches, ½ grated coconut, ...
# 6  [1 Head Broccoli, 10 Brussels Sprouts Sprouts,...
#
#                                     Diet Type  Calories  Time  \
# 0            [Vegan, Vegetarian, Pescatarian]       225     0
# 1            [Vegan, Vegetarian, Pescatarian]       652    38
# 2            [Vegan, Vegetarian, Pescatarian]      1824     0
# 3  [Sugar-Conscious, Vegetarian, Pescatarian]      1515     0
# 5            [Vegan, Vegetarian, Pescatarian]       577    20
# 6            [Vegetarian, Pescatarian, Paleo]      1181     0
#
#          Meal Type         Cuisine  \
# 0  [Lunch, Dinner]         Italian
# 1  [Lunch, Dinner]         Italian
# 2  [Lunch, Dinner]         Italian
# 3  [Lunch, Dinner]  Central europe
# 5  [Lunch, Dinner]          Indian
# 6  [Lunch, Dinner]         Italian
#
#                                           Recipe URL
# 0  https://www.marthastewart.com/924840/steamed-b...
# 1   https://food52.com/recipes/6823-grilled-broccoli
# 2  http://www.bonappetit.com/recipes/2003/06/broc...
# 3          http://www.bbcgoodfood.com/recipes/12689/
# 5  http://honestcooking.com/usili-curry-broccoli-...
# 6  http://glutenfreegirl.com/2010/01/broccoli-win...

# %%
def filter_cuisine(df, cuisine):
    filtered_df = df[df["Cuisine"]== cuisine.capitalize()]
    return filtered_df

# %%
filter_cuisine(data, "Italian")
# Out:
#                                          Recipe Name  \
# 0                                   Steamed Broccoli
# 1                                   Grilled Broccoli
# 2  Broccoli And Broccoli Rabe With Roasted Red Pe...
# 6                               Broccoli Winter Slaw
# 7              Christmas Broccoli: Broccoli Soffriti
#
#                                          Ingredients  \
# 0  [1 bunch broccoli, Dijon Vinaigrette, for serv...
# 1  [2 heads broccoli, 2 tablespoons olive oil, 1/...
# 2  [3 large red bell peppers, 4 pounds broccoli, ...
# 6  [1 Head Broccoli, 10 Brussels Sprouts Sprouts,...
# 7  [3 pounds fresh broccoli, with leaves, or broc...
#
#                                        Diet Type  Calories  Time  \
# 0               [Vegan, Vegetarian, Pescatarian]       225     0
# 1               [Vegan, Vegetarian, Pescatarian]       652    38
# 2               [Vegan, Vegetarian, Pescatarian]      1824     0
# 6               [Vegetarian, Pescatarian, Paleo]      1181     0
# 7  [Sugar-Conscious, Keto-Friendly, Pescatarian]       896    25
#
#          Meal Type  Cuisine                                         Recipe URL
# 0  [Lunch, Dinner]  Italian  https://www.marthastewart.com/924840/steamed-b...
# 1  [Lunch, Dinner]  Italian   https://food52.com/recipes/6823-grilled-broccoli
# 2  [Lunch, Dinner]  Italian  http://www.bonappetit.com/recipes/2003/06/broc...
# 6  [Lunch, Dinner]  Italian  http://glutenfreegirl.com/2010/01/broccoli-win...
# 7  [Lunch, Dinner]  Italian  https://www.foodnetwork.com/recipes/mario-bata...

# %%
def filter_meal_type(df, meal):
    filtered_df = df[df["Meal Type"].apply(lambda x: meal.capitalize() in x)]
    return filtered_df

# %%
filter_meal_type(data, "Lunch")
# Out:
#                                          Recipe Name  \
# 0                                   Steamed Broccoli
# 1                                   Grilled Broccoli
# 2  Broccoli And Broccoli Rabe With Roasted Red Pe...
# 3                            Broccoli Baked Potatoes
# 4                                      Broccoli Beef
# 5              Usili Curry with Broccoli and Coconut
# 6                               Broccoli Winter Slaw
# 7              Christmas Broccoli: Broccoli Soffriti
# 8                  Broccoli Cheese Casserole recipes
# 9                                     Broccoli Salad
#
#                                          Ingredients  \
# 0  [1 bunch broccoli, Dijon Vinaigrette, for serv...
# 1  [2 heads broccoli, 2 tablespoons olive oil, 1/...
# 2  [3 large red bell peppers, 4 pounds broccoli, ...
# 3  [1 egg , beaten, 140.0g grated cheddar, 300.0g...
# 4  [2 teaspoons soy sauce, 1 teaspoons Shaoxing w...
# 5  [2 medium broccoli bunches, ½ grated coconut, ...
# 6  [1 Head Broccoli, 10 Brussels Sprouts Sprouts,...
# 7  [3 pounds fresh broccoli, with leaves, or broc...
# 8  [2 pounds broccoli, stems removed (can use veg...
# 9  [3 heads Broccoli, 1 x Red onion, 6 slices Bac...
#
#                                        Diet Type  Calories  Time  \
# 0               [Vegan, Vegetarian, Pescatarian]       225     0
# 1               [Vegan, Vegetarian, Pescatarian]       652    38
# 2               [Vegan, Vegetarian, Pescatarian]      1824     0
# 3     [Sugar-Conscious, Vegetarian, Pescatarian]      1515     0
# 4            [Dairy-Free, Egg-Free, Peanut-Free]      1066     0
# 5               [Vegan, Vegetarian, Pescatarian]       577    20
# 6               [Vegetarian, Pescatarian, Paleo]      1181     0
# 7  [Sugar-Conscious, Keto-Friendly, Pescatarian]       896    25
# 8         [Peanut-Free, Tree-Nut-Free, Soy-Free]      2817    55
# 9          [Dairy-Free, Gluten-Free, Wheat-Free]      3514     0
#
#          Meal Type         Cuisine  \
# 0  [Lunch, Dinner]         Italian
# 1  [Lunch, Dinner]         Italian
# 2  [Lunch, Dinner]         Italian
# 3  [Lunch, Dinner]  Central europe
# 4  [Lunch, Dinner]         British
# 5  [Lunch, Dinner]          Indian
# 6  [Lunch, Dinner]         Italian
# 7  [Lunch, Dinner]         Italian
# 8  [Lunch, Dinner]          French
# 9  [Lunch, Dinner]        American
#
#                                           Recipe URL
# 0  https://www.marthastewart.com/924840/steamed-b...
# 1   https://food52.com/recipes/6823-grilled-broccoli
# 2  http://www.bonappetit.com/recipes/2003/06/broc...
# 3          http://www.bbcgoodfood.com/recipes/12689/
# 4           http://norecipes.com/blog/broccoli-beef/
# 5  http://honestcooking.com/usili-curry-broccoli-...
# 6  http://glutenfreegirl.com/2010/01/broccoli-win...
# 7  https://www.foodnetwork.com/recipes/mario-bata...
# 8  http://www.simplyrecipes.com/recipes/broccoli_...
# 9  http://userealbutter.com/2009/02/22/broccoli-s...

# %%
list_of_ingredients = ["eggplants", "egg", "rice", "onion" ]

# %%
def filter_ingredients(df, ingredient):
    filtered_df = df[df["Ingredients"].apply(lambda x: any(ingredient.lower() in word.lower() for word in x))]
    return filtered_df

# %%
filter_ingredients(data, "egg")
# Out:
#                          Recipe Name  \
# 3            Broccoli Baked Potatoes
# 8  Broccoli Cheese Casserole recipes
#
#                                          Ingredients  \
# 3  [1 egg , beaten, 140.0g grated cheddar, 300.0g...
# 8  [2 pounds broccoli, stems removed (can use veg...
#
#                                     Diet Type  Calories  Time  \
# 3  [Sugar-Conscious, Vegetarian, Pescatarian]      1515     0
# 8      [Peanut-Free, Tree-Nut-Free, Soy-Free]      2817    55
#
#          Meal Type         Cuisine  \
# 3  [Lunch, Dinner]  Central europe
# 8  [Lunch, Dinner]          French
#
#                                           Recipe URL
# 3          http://www.bbcgoodfood.com/recipes/12689/
# 8  http://www.simplyrecipes.com/recipes/broccoli_...
